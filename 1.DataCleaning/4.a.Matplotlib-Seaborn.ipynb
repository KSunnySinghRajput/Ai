# %% [markdown]
# # <center>[Seaborn](https://seaborn.pydata.org/tutorial.html)</center>
# **Important Features of Seaborn**
# - Built in themes for styling matplotlib graphics
# - Visualizing univariate and bivariate data
# - Fitting in and visualizing linear regression models
# - Plotting statistical time series data
# - Seaborn works well with NumPy and Pandas data structures
# - It comes with built in themes for styling Matplotlib graphics

# %%
# pip install seaborn

# %%
from matplotlib import pyplot as plt
import pandas as df
import numpy as np

# %% [markdown]
# # Figure Aesthetic

# %%
def sinplot(flip = 1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 5): 
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %% [markdown]
# **matplotlib**

# %%
sinplot()
plt.show()

# %% [markdown]
# **matplotlib, seaborn**

# %%
import seaborn as sb
sb.set()
sinplot()
plt.show()

# %% [markdown]
# # Importing Datasets and Libraries

# %%
print()
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
# Seaborn for plotting and styling
import seaborn as sb
df = sb.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **seaborn.color_palette(palette = None, n_colors = None, desat = None)**
#
# - palette = (Deep, Muted, Bright, Pastel, Dark, Colorblind)
# - n_colors : Number of colors in the palette. If None, the default will depend on how palette is specified. By default the value of n_colors is 6 colors.
# - desat : Proportion to desaturate each color.

# %%
current_palette = sb.color_palette()
sb.palplot(current_palette)
plt.show()

# %%
current_palette = sb.color_palette()
sb.palplot(sb.color_palette("Greens"))
plt.show()

# %%
import seaborn as sb
current_palette = sb.color_palette()
sb.palplot(sb.color_palette("BrBG", 7))
plt.show()

# %% [markdown]
# **seaborn.set_palette()**

# %%
import seaborn as sb
sb.set_style("white")
sb.set_palette("husl")
sinplot()
plt.show()

# %% [markdown]
# **seaborn.distplot()**
#
# - data : Series, 1d array or a list
# - bins - Specification of hist bins
# - hist : bool
# - kde : bool

# %% [markdown]
# ##  Figure Styles
# **Seaborn.set_style()**
#
# - Darkgrid
# - Whitegrid
# - Dark
# - White
# - Ticks

# %%
sb.set_style("whitegrid")
sinplot()
plt.show()

# %% [markdown]
# **Seaborn.despine()**

# %%
#Removing Axes Spines
sb.set_style("white")
sb.despine()
sinplot()
plt.show()

# %% [raw]
# {'axes.axisbelow'     : False,
# 'axes.edgecolor'      : 'white',
# 'axes.facecolor'      : '#EAEAF2',
# 'axes.grid'           : True,
# 'axes.labelcolor'     : '.15',
# 'axes.linewidth'      : 0.0,
# 'figure.facecolor'    : 'white',
# 'font.family'         : [u'sans-serif'],
# 'font.sans-serif'     : [u'Arial', u'Liberation
#                         Sans', u'Bitstream Vera Sans', u'sans-serif'],
# 'grid.color'          : 'white',
# 'grid.linestyle'      : u'-',
# 'image.cmap'          : u'Greys',
# 'legend.frameon'      : False,
# 'legend.numpoints'    : 1,
# 'legend.scatterpoints': 1,
# 'lines.solid_capstyle': u'round',
# 'text.color'          : '.15',
# 'xtick.color'         : '.15',
# 'xtick.direction'     : u'out',
# 'xtick.major.size'    : 0.0,
# 'xtick.minor.size'    : 0.0,
# 'ytick.color'         : '.15',
# 'ytick.direction'     : u'out',
# 'ytick.major.size'    : 0.0,
# 'ytick.minor.size'    : 0.0}

# %%
sb.set_style("darkgrid", {'axes.axisbelow': False})
sinplot()
sb.despine()
plt.show()

# %% [markdown]
# ## set_context()
# **Scaling Plot**
# - Paper
# - Notebook
# - Talk
# - Poster

# %%
sb.set_style("darkgrid", {'axes.axisbelow': False})
sinplot()
sb.despine()
plt.show()

# %% [markdown]
# # Histogram

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.distplot(df['petal_length'],kde = False)
plt.show()

# %% [markdown]
# # Kernel Density Estimates

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.distplot(df['petal_length'],rug=True, hist=False)
sb.despine()
plt.show()
#help(sb.distplot)

# %%
#Fitting Parametric Distribution

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.distplot(df['petal_length'])
sb.despine()
plt.show()

# %%
# Plotting Bivariate Distribution

# %% [markdown]
# **Scatter Plot**

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.jointplot(x = 'petal_length',y = 'petal_width',data = df)
plt.show()

# %% [markdown]
# **Hexbin Plot**

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.jointplot(x = 'petal_length',y = 'petal_width',data = df,kind = 'hex')
plt.show()

# %%
# Kernel Density Estimation

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.jointplot(x = 'petal_length',y = 'petal_width',data = df,kind = 'hex')
sb.color_palette("rocket", as_cmap=True)
plt.show()

# %% [markdown]
# # Visualizing Pairwise Relationship
#
# **seaborn.pairplot(data,…)**
# - data : Dataframe
# - hue : Variable in data to map plot aspects to different colors.
# - palette : Set of colors for mapping the hue variable
# - kind : Kind of plot for the non-identity relationships. {‘scatter’, ‘reg’}
# - diag_kind : Kind of plot for the diagonal subplots. {‘hist’, ‘kde’}

# %%
df = sb.load_dataset('iris')
sb.set_style("ticks")
sb.pairplot(df,hue = 'species',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %% [markdown]
# # Plotting Categorical Data
# ## Categorical Scatter Plots
# **Seaborn.stripplot()**

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.stripplot(x = "species", y = "petal_length", data = df,jitter = False)
plt.show()

# %%
df = sb.load_dataset('iris')
sb.stripplot(x = "species", y = "petal_length", data = df, jitter = True)
plt.show()

# %% [markdown]
# **Seaborn.Swarmplot()**

# %%
df = sb.load_dataset('iris')
sb.swarmplot(x = "species", y = "petal_length", data = df)
plt.show()
# Out:
# d:\pythonenv\base3.7\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Distribution of Observations

# %%
df = sb.load_dataset('iris')
sb.boxplot(x = "species", y = "petal_length", data = df)
plt.show()

# %% [markdown]
# **Seaborn.violinplot()**

# %%
df = sb.load_dataset('tips')
sb.violinplot(x = "day", y = "total_bill", data=df)
plt.show()

# %%
df = sb.load_dataset('tips')
sb.violinplot(x = "day", y = "total_bill",hue = 'sex', data = df)
plt.show()

# %%
df = sb.load_dataset('titanic')
sb.barplot(x = "sex", y = "survived", hue = "class", data = df)
plt.show()

# %%
df = sb.load_dataset('titanic')
sb.countplot(x = "class", data = df, palette = "Blues");
plt.show()

# %%
df = sb.load_dataset('titanic')
sb.pointplot(x = "sex", y = "survived", hue = "class", data = df)
plt.show()

# %%
df = sb.load_dataset('iris')
sb.boxplot(data = df, orient = "h")
plt.show()

# %%
df = sb.load_dataset('iris')
sb.boxplot(data = df, orient = "h")
plt.show()

# %%
df = sb.load_dataset('exercise')
sb.factorplot(x = "time", y = "pulse", hue = "kind", data = df);
plt.show()
# Out:
# d:\pythonenv\base3.7\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df = sb.load_dataset('exercise')
sb.factorplot(x = "time", y = "pulse", hue = "kind", kind = 'violin',data = df);
plt.show()
# Out:
# d:\pythonenv\base3.7\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df = sb.load_dataset('exercise')
sb.factorplot(x = "time", y = "pulse", hue = "kind", kind = 'violin', col = "diet", data = df);
plt.show()
# Out:
# d:\pythonenv\base3.7\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df = sb.load_dataset('titanic')
sb.factorplot("alive", col = "deck", col_wrap = 3,data = df[df.deck.notnull()],kind = "count")
plt.show()
# Out:
# d:\pythonenv\base3.7\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# d:\pythonenv\base3.7\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df = sb.load_dataset('tips')
sb.regplot(x = "total_bill", y = "tip", data = df)
sb.lmplot(x = "total_bill", y = "tip", data = df)
plt.show()

# %%
df = sb.load_dataset('tips')
sb.lmplot(x = "size", y = "tip", data = df)
plt.show()

# %%
df = sb.load_dataset('anscombe')
sb.lmplot(x="x", y="y", data=df.query("dataset == 'I'"))
plt.show()

# %%
df = sb.load_dataset('anscombe')
sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"))
plt.show()

# %%
df = sb.load_dataset('anscombe')
sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"),order = 2)
plt.show()
