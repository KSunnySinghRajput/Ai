# %%
#https://pillow.readthedocs.io/en/stable/index.html
from PIL import Image as ima
#help(Image)

# %%
Im = ima.open("_pic\\1.png")
print (Im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x750 at 0x2A43965F808>

# %%
#Image Attributes
Im.filename
# Out:
# '_pic\\1.png'

# %%
Im.size
# Out:
# (500, 750)

# %%
Im.width
# Out:
# 500

# %%
Im.height
# Out:
# 750

# %%
Im.format
# Out:
# 'PNG'

# %%
Im.mode
# Out:
# 'RGB'

# %%
Im.info
# Out:
# {'icc_profile': b'\x00\x00\x020ADBE\x02\x10\x00\x00mntrRGB XYZ \x07\xcf\x00\x06\x00\x03\x00\x00\x00\x00\x00\x00acspAPPL\x00\x00\x00\x00none\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-ADBE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ncprt\x00\x00\x00\xfc\x00\x00\x002desc\x00\x00\x010\x00\x00\x00kwtpt\x00\x00\x01\x9c\x00\x00\x00\x14bkpt\x00\x00\x01\xb0\x00\x00\x00\x14rTRC\x00\x00\x01\xc4\x00\x00\x00\x0egTRC\x00\x00\x01\xd4\x00\x00\x00\x0ebTRC\x00\x00\x01\xe4\x00\x00\x00\x0erXYZ\x00\x00\x01\xf4\x00\x00\x00\x14gXYZ\x00\x00\x02\x08\x00\x00\x00\x14bXYZ\x00\x00\x02\x1c\x00\x00\x00\x14text\x00\x00\x00\x00Copyright 1999 Adobe Systems Incorporated\x00\x00\x00desc\x00\x00\x00\x00\x00\x00\x00\x11Adobe RGB (1998)\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00
# ...

# %%
#paint Views
#Im.show()

# %%
from IPython.display import Image
display(Im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x750 at 0x2A43965F808>

# %%
new_image = Im.resize((400, 400))
new_image.save("_temp\\01_temp" + ".jpeg", "JPEG")
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x2A43970FB48>

# %%
size = 128, 128
new_image.thumbnail(size)
new_image.save("_temp\\01" + ".thumbnail", "JPEG")
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2A43970FB48>

# %%
#Image processing
from IPython.display import Image 
im1= ima.open("_pic\\1.png")
im2=ima.open("_pic\\2.png")
im3=ima.alpha_composite(im1, im2)
display(im3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-5a9a48d28476> in <module>
#       3 im1= ima.open("_pic\\1.png")
#       4 im2=ima.open("_pic\\2.png")
# ----> 5 im3=ima.alpha_composite(im1, im2)
#       6 display(im3)
#
# d:\pythonenv\base3.7\lib\site-packages\PIL\Image.py in alpha_composite(im1, im2)
#    2962     im1.load()
#    2963     im2.load()
# -> 2964     return im1._new(core.alpha_composite(im1.im, im2.im))
#    2965
#    2966
#
# ValueError: image has wrong mode
