# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - ‘bar’ or ‘barh’ for bar plots
# - ‘hist’ for histogram
# - ‘box’ for boxplot
# - ‘kde’ or ‘density’ for density plots
# - ‘area’ for area plots
# - ‘scatter’ for scatter plots
# - ‘hexbin’ for hexagonal bin plots
# - ‘pie’ for pie plots

# %%
# df = pd.DataFrame({'a': np.random.randn(1000) + 1, 
#                    'b': np.random.randn(1000),
#                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# index=pd.date_range('1/1/2000', periods=1000)
# df = pd.DataFrame(np.random.randn(1000, 4), index=index, columns=list('ABCD'))

# %% [markdown]
# ## 1. Plot

# %%
plt.close('all')

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000', periods=1000))
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts = ts.cumsum()       # cumulative sum
ts.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()
plt.figure();
df.plot();

# %%
df = df.cumsum()
plt.figure();
df.plot();
df
# Out:
#                     A          B          C          D
# 2000-01-01   0.523293  -0.821252   1.677277   0.195765
# 2000-01-02   0.580340   0.205097   2.124958  -0.150410
# 2000-01-03   2.267504  -0.348051   3.835794   0.003699
# 2000-01-04   3.665726  -0.466165   4.704187   0.451433
# 2000-01-05   3.869670  -0.572429   5.273058   0.888934
# ...               ...        ...        ...        ...
# 2002-09-22  89.957181  22.090047  10.227545  11.406029
# 2002-09-23  87.541206  23.117368   9.275366  11.157110
# 2002-09-24  87.777443  22.253460   9.105196  11.813479
# 2002-09-25  86.746030  22.473056  11.630232  14.268348
# 2002-09-26  84.679453  23.950404  12.908026  14.565490
#
# [1000 rows x 4 columns]

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()
df['A'] = pd.Series(list(range(len(df))))
df.plot(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A'>

# %% [markdown]
# ### Bar plots

# %%
index=pd.date_range('1/1/2000', periods=500)
df = pd.DataFrame(np.random.randn(500, 4), index=index, columns=list('ABCD'))
# df = df.cumsum()
# plt.figure();

# %%
df.iloc[5].plot(kind='bar');

# %%
df.iloc[5].plot.bar()
plt.axhline(0, color='k');

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot.bar();

# %%
 df2.plot.bar(stacked=True);

# %%
 df2.plot.barh(stacked=True);

# %% [markdown]
# ### Histograms¶

# %%
df = pd.DataFrame({'a': np.random.randn(1000) + 1, 
                    'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])
# plt.figure();

# %%
df.plot.hist(alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(stacked=True, bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['a'].plot.hist(orientation='horizontal', cumulative=True)
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df['a'].diff().hist()
# Out:
# <AxesSubplot:>

# %%
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>, <AxesSubplot:>]], dtype=object)

# %%
df = pd.Series(np.random.randn(1000))
df.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4))
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ### Area plot

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot.area();

# %%
df.plot.area(stacked=False);

# %% [markdown]
# ### Scatter plot

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot.scatter(x='a', y='b')
df.plot.scatter(x='a', y='c');

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1');
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax);

# %%
df.plot.scatter(x='a', y='b', c='c', s=50);

# %%
df.plot.scatter(x='a', y='b', s=df['c'] * 200);
