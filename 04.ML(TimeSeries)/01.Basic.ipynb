# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# DATASET :https://www.kaggle.com/kashnitsky/mlcourse?select=ads.csv

# %% [markdown]
# # Time Series Analysis

# %%
raw_data = pd.read_csv("_dataset/TimeSeries.csv",sep=",")
raw_data.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
raw_data['date'] =  pd.to_datetime(raw_data['Date'], format='%Y-%m-%d')
raw_data['Date'] =  pd.to_datetime(raw_data['Date'], format='%Y-%m-%d')
raw_data = raw_data.set_index('Date')
df = raw_data
df.head()
# Out:
#             Temp       date
# Date
# 1981-01-01  20.7 1981-01-01
# 1981-01-02  17.9 1981-01-02
# 1981-01-03  18.8 1981-01-03
# 1981-01-04  14.6 1981-01-04
# 1981-01-05  15.8 1981-01-05

# %%
def plot_df(df, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

# %%
def scater_df(df, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.scatter(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

# %%
scater_df(df, x=df.index, y=df.Temp, title='Time Series')

# %%
plot_df(df, x=df.index, y=df.Temp, title='Time Series')

# %%
X=df.iloc[:,1].values   #2d
y = df.iloc[:,0].values

# %%
from sklearn.model_selection  import train_test_split 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

# %%
plt.figure(figsize=(16,5), dpi=100)
plt.scatter(X_test,  y_test , color='tab:red')
plt.scatter(X_train, y_train, color='tab:green')
plt.gca().set(title="TimeSeries", xlabel="Date", ylabel="temp")
plt.show()

# %%
import sklearn.metrics as metrics
def regression_results(y_true, y_pred):# Regression metrics
    explained_variance=metrics.explained_variance_score(y_true, y_pred)
    mean_absolute_error=metrics.mean_absolute_error(y_true, y_pred) 
    mse=metrics.mean_squared_error(y_true, y_pred) 
    mean_squared_log_error=metrics.mean_squared_log_error(y_true, y_pred)
    median_absolute_error=metrics.median_absolute_error(y_true, y_pred)
    r2=metrics.r2_score(y_true, y_pred)
    print('explained_variance: ', round(explained_variance,4))    
    print('mean_squared_log_error: ', round(mean_squared_log_error,4))
    print('r2: ', round(r2,4))
    print('MAE: ', round(mean_absolute_error,4))
    print('MSE: ', round(mse,4))
    print('RMSE: ', round(np.sqrt(mse),4))

# %%
from sklearn.linear_model import LinearRegression
reg1=LinearRegression()#initialize model
reg1.fit(X_train,y_train)#train the model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-bfc106d818c0> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 reg1=LinearRegression()#initialize model
# ----> 3 reg1.fit(X_train,y_train)#train the model
#
# /media/mastersupc/WorkSpace/pyenv3.8/lib/python3.8/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# /media/mastersupc/WorkSpace/pyenv3.8/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
# ...

# %%
pred_train=reg.predict(X_train)

# %%
regression_results(y, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-6a17a2cc6085> in <module>
# ----> 1 regression_results(y, y_pred)
#
# NameError: name 'y_pred' is not defined
