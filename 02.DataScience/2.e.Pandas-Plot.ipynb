# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - ‘bar’ or ‘barh’ for bar plots
# - ‘hist’ for histogram
# - ‘box’ for boxplot
# - ‘kde’ or ‘density’ for density plots
# - ‘area’ for area plots
# - ‘scatter’ for scatter plots
# - ‘hexbin’ for hexagonal bin plots
# - ‘pie’ for pie plots

# %%
# df = pd.DataFrame({'a': np.random.randn(1000) + 1, 
#                    'b': np.random.randn(1000),
#                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# index=pd.date_range('1/1/2000', periods=1000)
# df = pd.DataFrame(np.random.randn(1000, 4), index=index, columns=list('ABCD'))

# %% [markdown]
# ## 1. Plot

# %%
plt.close('all')

# %%
a=pd.date_range('1/1/2000', periods=1000)
a
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20',
#                '2002-09-21', '2002-09-22', '2002-09-23', '2002-09-24',
#                '2002-09-25', '2002-09-26'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000', periods=1000))
ts
# Out:
# 2000-01-01   -0.369479
# 2000-01-02   -1.601787
# 2000-01-03    0.676453
# 2000-01-04    0.234118
# 2000-01-05    0.091103
#                 ...
# 2002-09-22   -0.407003
# 2002-09-23   -0.387980
# 2002-09-24    1.066957
# 2002-09-25    0.078963
# 2002-09-26    1.565529
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts = ts.cumsum()       # cumulative sum
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts=pd.date_range('1/1/2000', periods=1000)
df = pd.DataFrame(np.random.randn(1000, 4), index=ts, columns=list('ABCD'))
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01  0.001413  0.533895  0.641571  0.298974
# 2000-01-02  0.473452 -0.291295 -0.406903  0.381706
# 2000-01-03  0.339951 -1.508967  1.100437 -1.883765
# 2000-01-04  0.790713  1.087859 -0.361599 -0.461389
# 2000-01-05 -0.271832  0.968019  1.364297 -0.000679

# %%
df = df.cumsum()

# %%
plt.figure()
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = df.cumsum()
plt.figure()
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = df.cumsum()
plt.figure()
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()
df['A'] = pd.Series(list(range(len(df))))
df.plot(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A'>

# %%
df[['A','B']].plot()
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.randn(1000, 6))
df.head()
# Out:
#           0         1         2         3         4         5
# 0 -0.793156  0.883125  0.391322 -1.141068  0.957127 -0.295806
# 1 -0.862315  0.672274 -0.589702 -1.074698  0.454652  0.302121
# 2  2.240727  0.570962  0.082777  1.743093  0.208353 -1.265284
# 3 -0.421870 -0.320676 -1.465960  0.310521 -0.609142  1.683604
# 4 -0.752372 -0.774056 -0.052767  1.604546  0.410149  0.460335

# %%
# df.loc[:,[5]]
# df.iloc[5]  # row
# df.iloc[:,5]  # row All ,Col 0 to 5

# %% [markdown]
# ### Bar plots

# %%
index=pd.date_range('1/1/2000', periods=500)
df = pd.DataFrame(np.random.randn(500, 4), index=index, columns=list('ABCD'))
# df = df.cumsum()
# plt.figure();

# %%
df.iloc[4].head()
# Out:
# A   -0.415090
# B    0.495251
# C    2.182435
# D    0.049967
# Name: 2000-01-06 00:00:00, dtype: float64

# %%
df.iloc[5].plot(kind='bar');

# %%
df.iloc[5].plot.bar()
plt.axhline(0, color='k');

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot.bar();

# %%
 df2.plot.bar(stacked=True);

# %%
 df2.plot.barh(stacked=True);

# %% [markdown]
# ### Histograms¶

# %%
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)
#     Plot a histogram.
#
#     Compute and draw the histogram of *x*.  The return value is a tuple
#     (*n*, *bins*, *patches*) or ([*n0*, *n1*, ...], *bins*, [*patches0*,
#     *patches1*, ...]) if the input contains multiple data.  See the
#     documentation of the *weights* parameter to draw a histogram of
#     already-binned data.
#
#     Multiple data can be provided via *x* as a list of datasets
#     of potentially different length ([*x0*, *x1*, ...]), or as
#     a 2-D ndarray in which each column is a dataset.  Note that
#     the ndarray form is transposed relative to the list form.
#
#     Masked arrays are not supported.
#
# ...

# %%
df = pd.DataFrame({'a': np.random.randn(1000) + 1, 
                    'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])
# plt.figure();

# %%
df.plot.hist(alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(stacked=True, bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['a'].plot.hist(orientation='horizontal', cumulative=True)
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df['a'].diff().hist()
# Out:
# <AxesSubplot:>

# %%
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>, <AxesSubplot:>]], dtype=object)

# %%
df = pd.Series(np.random.randn(1000))
df

# %%
df.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4))
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ### Area plot

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot.area();

# %%
df.plot.area(stacked=False);

# %% [markdown]
# ### Scatter plot

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
#            a         b         c         d
# 0   0.031131  0.758808  0.305457  0.018819
# 1   0.952710  0.201953  0.736039  0.640405
# 2   0.378572  0.317048  0.646792  0.989854
# 3   0.463406  0.709139  0.226121  0.218120
# 4   0.604950  0.908334  0.941674  0.693800
# 5   0.801848  0.635840  0.229716  0.487432
# 6   0.477752  0.197311  0.058406  0.113342
# 7   0.768639  0.691633  0.452391  0.773467
# 8   0.751027  0.459619  0.203073  0.690770
# 9   0.875301  0.533340  0.874491  0.232037
# 10  0.529328  0.598399  0.028101  0.712978
# 11  0.878830  0.950218  0.371704  0.167795
# 12  0.462328  0.565200  0.114893  0.241908
# 13  0.445692  0.860951  0.767590  0.886815
# 14  0.799100  0.929330  0.165982  0.755164
# 15  0.001328  0.943678  0.285115  0.324863
# 16  0.024779  0.774987  0.171524  0.272529
# 17  0.742623  0.746578  0.643432  0.555875
# 18  0.449733  0.837542  0.627036  0.768335
# 19  0.905189  0.022571  0.987095  0.341046
# 20  0.960445  0.787340  0.936421  0.486775
# ...

# %%
df.plot.scatter(x='a', y='b')
plt.show()

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1');
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax);

# %%
df.plot.scatter(x='a', y='b', c='c', s=50);  # s size

# %%
df.plot.scatter(x='a', y='b', s=df['c'] * 200);
