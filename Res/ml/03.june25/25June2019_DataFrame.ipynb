# %%
import pandas as pd

# %%
df=pd.read_csv('dataset/titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-31b92b8a292b> in <module>
# ----> 1 df=pd.read_csv('dataset/titanic.csv')
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# ...

# %%
df.shape

# %%
df.columns

# %%
df.head(2)

# %%
#s=df.Survived
s=df['Survived']

# %%
type(s)

# %%
df.Survived.unique()

# %%
df.gender.unique()

# %%
df.Survived.value_counts()

# %%
df.gender.value_counts()

# %%
df[df.Survived==1].shape

# %%
df[(df.Survived==1)& (df.gender=='male')].shape

# %%
df[(df.Survived==1)& (df.gender=='female')].shape

# %%
df[df.Age<10].shape

# %%
df[(df.Age<10) & (df.Survived==1)].shape

# %%
df[(df.Age>0) &(df.Age<20)].shape

# %%
df[df.Age.isin(range(1,20))].shape

# %%
df.shape

# %%
df.head(6)

# %%
df.Age.isnull()
df.Age.isnull().sum()

# %%
df.isnull().sum()

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df.shape

# %%
s='india'

# %%
len(s)

# %%
names=df.Name

# %%
size=[]
for n in names:
    size.append(len(n))

# %%
l=df.Name.apply(len)

# %%
l=df.Name.map(len)

# %%
l
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
# 5      16
# 6      23
# 7      30
# 8      49
# 9      35
# 10     31
# 11     24
# 12     30
# 13     27
# 14     36
# 15     32
# 16     20
# 17     28
# 18     55
# 19     23
# 20     20
# 21     21
# 22     27
# 23     28
# 24     29
# 25     57
# 26     23
# 27     30
# 28     29
# 29     19
#        ..
# 861    27
# 862    51
# 863    33
# 864    22
# 865    24
# 866    28
# 867    36
# 868    27
# 869    31
# 870    17
# 871    48
# 872    24
# 873    27
# 874    37
# 875    32
# 876    29
# 877    20
# 878    18
# 879    45
# 880    44
# 881    18
# 882    28
# 883    29
# 884    22
# 885    36
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
df['gender']=df.gender.map({'male':1,'female':2})

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked', 'new_gender'],
#       dtype='object')

# %%
df.pop('new_gender')
# Out:
# 0      1
# 1      2
# 2      2
# 3      2
# 4      1
# 5      1
# 6      1
# 7      1
# 8      2
# 9      2
# 10     2
# 11     2
# 12     1
# 13     1
# 14     2
# 15     2
# 16     1
# 17     1
# 18     2
# 19     2
# 20     1
# 21     1
# 22     2
# 23     1
# 24     2
# 25     2
# 26     1
# 27     1
# 28     2
# 29     1
#       ..
# 861    1
# 862    2
# 863    2
# 864    1
# 865    2
# 866    2
# 867    1
# 868    1
# 869    1
# 870    1
# 871    2
# 872    1
# 873    1
# 874    2
# 875    2
# 876    1
# 877    1
# 878    1
# 879    2
# 880    2
# 881    1
# 882    2
# 883    1
# 884    1
# 885    2
# 886    1
# 887    2
# 888    2
# 889    1
# 890    1
# Name: new_gender, Length: 891, dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
sv=df.Survived

# %%
df.insert(0,'Survived1',sv)

# %%
df.head(1)
# Out:
#    Survived1  PassengerId  Survived  Pclass                     Name  gender  \
# 0          0            1         0       3  Braund, Mr. Owen Harris       1
#
#     Age  SibSp  Parch     Ticket  Fare Embarked
# 0  22.0      1      0  A/5 21171  7.25        S

# %%
df.pop('Survived')
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df.head(1)
# Out:
#    Survived1  PassengerId  Pclass                     Name  gender   Age  \
# 0          0            1       3  Braund, Mr. Owen Harris       1  22.0
#
#    SibSp  Parch     Ticket  Fare Embarked
# 0      1      0  A/5 21171  7.25        S

# %%
df.rename({'Survived1':'Survived'},axis=1,inplace=True)

# %%
df.head(1)
# Out:
#    Survived  PassengerId  Pclass                     Name  gender   Age  \
# 0         0            1       3  Braund, Mr. Owen Harris       1  22.0
#
#    SibSp  Parch     Ticket  Fare Embarked
# 0      1      0  A/5 21171  7.25        S

# %%
input_cols=df.iloc[:,1:]

# %%
output_cols=df.iloc[:,0]

# %%
input_cols.shape
# Out:
# (891, 10)

# %%
output_cols.shape
# Out:
# (891,)

# %%
output_cols
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
out_cols=df.iloc[:,0:1]

# %%
out_cols
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# 5           0
# 6           0
# 7           0
# 8           1
# 9           1
# 10          1
# 11          1
# 12          0
# 13          0
# 14          0
# 15          1
# 16          0
# 17          1
# 18          0
# 19          1
# 20          0
# 21          1
# 22          1
# 23          1
# 24          0
# 25          1
# 26          0
# 27          0
# 28          1
# 29          0
# ..        ...
# 861         0
# 862         1
# 863         0
# 864         0
# 865         1
# 866         1
# 867         0
# 868         0
# 869         1
# 870         0
# 871         1
# 872         0
# 873         0
# 874         1
# 875         1
# 876         0
# 877         0
# 878         0
# 879         1
# 880         1
# 881         0
# 882         0
# 883         0
# 884         0
# 885         0
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# ...

# %%
part1=df.iloc[:650,:]
part2=df.iloc[650:,:]

# %%
part1.shape
# Out:
# (650, 11)

# %%
part2.shape
# Out:
# (241, 11)

# %%
#df.loc[:,'PassengerId']
#df.loc[:,['PassengerId','Age','gender']]
df.loc[:,'Name':'Embarked']
# Out:
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris       1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       2  38.0      1
# 2                               Heikkinen, Miss. Laina       2  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       2  35.0      1
# 4                             Allen, Mr. William Henry       1  35.0      0
# 5                                     Moran, Mr. James       1   NaN      0
# 6                              McCarthy, Mr. Timothy J       1  54.0      0
# 7                       Palsson, Master. Gosta Leonard       1   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       2  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)       2  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut       2   4.0      1
# ...

# %%
df1=pd.read_excel('c:/dataset/movies_sheets.xls')

# %%
df2=pd.read_excel('c:/dataset/movies_sheets.xls',sheet_name=1)

# %%
df3=pd.read_excel('c:/dataset/movies_sheets.xls',sheet_name='2010s')

# %%
df1.shape
# Out:
# (1338, 25)

# %%
df2.shape
# Out:
# (2100, 25)

# %%
df3.shape
# Out:
# (1604, 25)

# %%
df1.append(df2)
dff=df1.append(df2,ignore_index=True)
dff=dff.append(df3,ignore_index=True)

# %%
dff.shape
# Out:
# (5042, 25)

# %%
dff.to_csv('c:/dataset/all_movies_data.csv')
